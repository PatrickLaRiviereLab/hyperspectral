# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Practice Plotting

# %%
x = [1, 2, 3, 4]
y = [2, 4, 1, 0]
plt.plot(x, y, label = "Plot")
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(y, x, label = "Inverse plot")
plt.legend()
